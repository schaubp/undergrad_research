# %%
# Make external packages available
from numpy import *
import matplotlib
# %pylab inline
import sys
import os
from astropy.io import ascii
from astropy.io import fits
from astropy import wcs
from astropy.wcs import WCS
from astropy import units as u
from astropy.coordinates import SkyCoord
from PIL import Image
import aplpy
from astropy.coordinates import SkyCoord, FK4, FK5, Galactic
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# [The above sets up python libraries that make the routines that we use work. Python comes with a (very) limited set of built-in features, and then uses libraries to allow it to do all sorts of truly impressive things - reading in data, plotting, statistics, etc.]

# %% [markdown]
# Read in the GHOSTS data.

# %%
#gh_data_01 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field01.newphoto_radec')
#gh_data_02 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field02.newphoto_radec')
#gh_data_03 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field03.newphoto_radec')
#gh_data_04 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field04.newphoto_radec')
#gh_data_05 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field05.newphoto_radec')
gh_data_06 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field06.newphoto_radec')
#gh_data_07 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field07.newphoto_radec')
gh_data_08 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field08.newphoto_radec')
#gh_data_09 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field09.newphoto_radec')
#gh_data_10 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field10.newphoto_radec')
#gh_data_11 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field11.newphoto_radec')
#gh_data_12 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field12.newphoto_radec')
#gh_data_13 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field13.newphoto_radec')
gh_data_14 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field14.newphoto_radec')
#gh_data_15 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field15.newphoto_radec')
gh_data_16 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field16.newphoto_radec')
gh_data_17 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field17.newphoto_radec')
#gh_data_18 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field18.newphoto_radec')
#gh_data_19 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field19.newphoto_radec')
gh_data_20 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field20.newphoto_radec')
#gh_data_21 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field21.newphoto_radec')
gh_data_22 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field22.newphoto_radec')
#gh_data_23 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field23.newphoto_radec')
gh_data_24 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field24.newphoto_radec')
#gh_data_25 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field25.newphoto_radec')
gh_data_26 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field26.newphoto_radec')
#gh_data_27 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field27.newphoto_radec')
gh_data_28 = ascii.read('http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field28.newphoto_radec')
# Out:
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field06.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field08.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field14.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field16.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field17.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field20.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field22.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field24.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field26.newphoto_radec [Done]
# Downloading http://www-personal.umich.edu/~ericbell/data/GHOSTS/ngc3031_culleddata/ngc3031-field28.newphoto_radec [Done]

# %% [markdown]
# Now we have read in the dataset. Now we take the columns, and put them in handy arrays that are named reasonably. The columns are always the same, so you don't have to futz with the next 4 lines. Columns 1 and 2 are x and y on the detector (i.e., it's position in the picture that HST's digital camera took); you don't really need that right now so we don't bother to give it its own variables.

# %%
#open fits file and get HI data cube
hdulist = fits.open('M81HIM0.fits')
primary_hdu = hdulist[0]
M81_HI = primary_hdu.data[0,:,:] #only want RA and dec, not frequency from first col
hdr = primary_hdu.header

w = WCS(hdr, naxis=[1,2])

# %%
#checking on some things
hdulist.info()

print w.naxis
print M81_HI.shape
print M81_HI[245, 245] #0 indexing
print median(M81_HI), mean(M81_HI)
# Out:
# Filename: M81HIM0.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     367   (579, 687, 1)   float32
# 2
# (687L, 579L)
# 50.9443
# 0.0 131.973

# %%
#primary_hdu.header

# %%
primary_hdu.header['TELESCOP']
# Out:
# 'VLA'

# %%
primary_hdu.header.comments['TELESCOP']
# Out:
# ''

# %%
plt.imshow(M81_HI, origin='lower')

# %%
pixra = list()
pixdec = list()
pixdata = list()
pixlist = list()
radecindex = 0
imax = len(M81_HI[1,:])/1
jmax = len(M81_HI[:,1])/1
for i in range(imax):
    for j in range(jmax):
        w_ra, w_dec = w.all_pix2world(i, j, 0)
        val = M81_HI[j, i]
        pixra.append(w_ra)
        pixdec.append(w_dec)
        pixdata.append(val)
        radecindex = radecindex+1
        
        pixlist.append([float(w_ra), float(w_dec), val])
        
        #plot(x="w_ra", y="w_dec", data={w_ra} fmt='k.')#, color=val)

print size(pixlist)
# Out:
# 1193319

# %%
#figuring out how data is arranged
print pixlist[0][0]
print pixlist[0][1]
print pixlist[0][2]
print pixlist[3]
print pixlist[4]
print pixlist[5]
# Out:
# 150.406963715
# 68.4144526319
# 0.0
# [150.40812747959254, 68.42277515231015, 0.0]
# [150.40851560558545, 68.42554932191055, 0.0]
# [150.4089038339509, 68.42832348958389, 0.0]

# %%
figure(figsize(579/74, 687/74))
plt.scatter(x=pixra, y=pixdec, c=pixdata, marker=',', edgecolors='none', cmap=matplotlib.cm.gray_r)
axis([max(pixra),min(pixra),min(pixdec),max(pixdec)])
xlabel('ra (1950)')
ylabel('dec (1950)')
plt.title('test')

# %%
ra_06 = gh_data_06['col5'][:]
dec_06 = gh_data_06['col6'][:]
f606_06 = gh_data_06['col3'][:]
f814_06 = gh_data_06['col4'][:]

ra_08 = gh_data_08['col5'][:]
dec_08 = gh_data_08['col6'][:]
f606_08 = gh_data_08['col3'][:]
f814_08 = gh_data_08['col4'][:]

ra_14 = gh_data_14['col5'][:]
dec_14 = gh_data_14['col6'][:]
f606_14 = gh_data_14['col3'][:]
f814_14 = gh_data_14['col4'][:]

ra_16 = gh_data_16['col5'][:]
dec_16 = gh_data_16['col6'][:]
f606_16 = gh_data_16['col3'][:]
f814_16 = gh_data_16['col4'][:]

ra_17 = gh_data_17['col5'][:]
dec_17 = gh_data_17['col6'][:]
f606_17 = gh_data_17['col3'][:]
f814_17 = gh_data_17['col4'][:]

ra_20 = gh_data_20['col5'][:]
dec_20 = gh_data_20['col6'][:]
f606_20 = gh_data_20['col3'][:]
f814_20 = gh_data_20['col4'][:]

ra_22 = gh_data_22['col5'][:]
dec_22 = gh_data_22['col6'][:]
f606_22 = gh_data_22['col3'][:]
f814_22 = gh_data_22['col4'][:]

ra_24 = gh_data_24['col5'][:]
dec_24 = gh_data_24['col6'][:]
f606_24 = gh_data_24['col3'][:]
f814_24 = gh_data_24['col4'][:]

ra_26 = gh_data_26['col5'][:]
dec_26 = gh_data_26['col6'][:]
f606_26 = gh_data_26['col3'][:]
f814_26 = gh_data_26['col4'][:]

ra_28 = gh_data_28['col5'][:]
dec_28 = gh_data_28['col6'][:]
f606_28 = gh_data_28['col3'][:]
f814_28 = gh_data_28['col4'][:]

# %% [markdown]
# ###SAME AS PREVIOUS CELL BUT WITH ALL FIELDS###
#
# ra_01 = gh_data_01['col5'][:]
# dec_01 = gh_data_01['col6'][:]
# f606_01 = gh_data_01['col3'][:] # Magnitude in F606W filter (zeropoint - 2.5log10(flux@606nm))
# f814_01 = gh_data_01['col4'][:] # Magnitude in F814W filter (zeropoint - 2.5log10(flux@814nm))
#
# ra_02 = gh_data_02['col5'][:]
# dec_02 = gh_data_02['col6'][:]
# f606_02 = gh_data_02['col3'][:]
# f814_02 = gh_data_02['col4'][:]
#
# ra_03 = gh_data_03['col5'][:]
# dec_03 = gh_data_03['col6'][:]
# f606_03 = gh_data_03['col3'][:]
# f814_03 = gh_data_03['col4'][:]
#
# ra_04 = gh_data_04['col5'][:]
# dec_04 = gh_data_04['col6'][:]
# f606_04 = gh_data_04['col3'][:]
# f814_04 = gh_data_04['col4'][:]
#
# ra_05 = gh_data_05['col5'][:]
# dec_05 = gh_data_05['col6'][:]
# f606_05 = gh_data_05['col3'][:]
# f814_05 = gh_data_05['col4'][:]
#
# ra_06 = gh_data_06['col5'][:]
# dec_06 = gh_data_06['col6'][:]
# f606_06 = gh_data_06['col3'][:]
# f814_06 = gh_data_06['col4'][:]
#
# ra_07 = gh_data_07['col5'][:]
# dec_07 = gh_data_07['col6'][:]
# f606_07 = gh_data_07['col3'][:]
# f814_07 = gh_data_07['col4'][:]
#
# ra_08 = gh_data_08['col5'][:]
# dec_08 = gh_data_08['col6'][:]
# f606_08 = gh_data_08['col3'][:]
# f814_08 = gh_data_08['col4'][:]
#
# ra_09 = gh_data_09['col5'][:]
# dec_09 = gh_data_09['col6'][:]
# f606_09 = gh_data_09['col3'][:]
# f814_09 = gh_data_09['col4'][:]
#
# ra_10 = gh_data_10['col5'][:]
# dec_10 = gh_data_10['col6'][:]
# f606_10 = gh_data_10['col3'][:]
# f814_10 = gh_data_10['col4'][:]
#
# ra_11 = gh_data_11['col5'][:]
# dec_11 = gh_data_11['col6'][:]
# f606_11 = gh_data_11['col3'][:]
# f814_11 = gh_data_11['col4'][:]
#
# ra_12 = gh_data_12['col5'][:]
# dec_12 = gh_data_12['col6'][:]
# f606_12 = gh_data_12['col3'][:]
# f814_12 = gh_data_12['col4'][:]
#
# ra_13 = gh_data_13['col5'][:]
# dec_13 = gh_data_13['col6'][:]
# f606_13 = gh_data_13['col3'][:]
# f814_13 = gh_data_13['col4'][:]
#
# ra_14 = gh_data_14['col5'][:]
# dec_14 = gh_data_14['col6'][:]
# f606_14 = gh_data_14['col3'][:]
# f814_14 = gh_data_14['col4'][:]
#
# ra_15 = gh_data_15['col5'][:]
# dec_15 = gh_data_15['col6'][:]
# f606_15 = gh_data_15['col3'][:]
# f814_15 = gh_data_15['col4'][:]
#
# ra_16 = gh_data_16['col5'][:]
# dec_16 = gh_data_16['col6'][:]
# f606_16 = gh_data_16['col3'][:]
# f814_16 = gh_data_16['col4'][:]
#
# ra_17 = gh_data_17['col5'][:]
# dec_17 = gh_data_17['col6'][:]
# f606_17 = gh_data_17['col3'][:]
# f814_17 = gh_data_17['col4'][:]
#
# ra_18 = gh_data_18['col5'][:]
# dec_18 = gh_data_18['col6'][:]
# f606_18 = gh_data_18['col3'][:]
# f814_18 = gh_data_18['col4'][:]
#
# ra_19 = gh_data_19['col5'][:]
# dec_19 = gh_data_19['col6'][:]
# f606_19 = gh_data_19['col3'][:]
# f814_19 = gh_data_19['col4'][:]
#
# ra_20 = gh_data_20['col5'][:]
# dec_20 = gh_data_20['col6'][:]
# f606_20 = gh_data_20['col3'][:]
# f814_20 = gh_data_20['col4'][:]
#
# ra_21 = gh_data_21['col5'][:]
# dec_21 = gh_data_21['col6'][:]
# f606_21 = gh_data_21['col3'][:]
# f814_21 = gh_data_21['col4'][:]
#
# ra_22 = gh_data_22['col5'][:]
# dec_22 = gh_data_22['col6'][:]
# f606_22 = gh_data_22['col3'][:]
# f814_22 = gh_data_22['col4'][:]
#
# ra_23 = gh_data_23['col5'][:]
# dec_23 = gh_data_23['col6'][:]
# f606_23 = gh_data_23['col3'][:]
# f814_23 = gh_data_23['col4'][:]
#
# ra_24 = gh_data_24['col5'][:]
# dec_24 = gh_data_24['col6'][:]
# f606_24 = gh_data_24['col3'][:]
# f814_24 = gh_data_24['col4'][:]
#
# ra_25 = gh_data_25['col5'][:]
# dec_25 = gh_data_25['col6'][:]
# f606_25 = gh_data_25['col3'][:]
# f814_25 = gh_data_25['col4'][:]
#
# ra_26 = gh_data_26['col5'][:]
# dec_26 = gh_data_26['col6'][:]
# f606_26 = gh_data_26['col3'][:]
# f814_26 = gh_data_26['col4'][:]
#
# ra_27 = gh_data_27['col5'][:]
# dec_27 = gh_data_27['col6'][:]
# f606_27 = gh_data_27['col3'][:]
# f814_27 = gh_data_27['col4'][:]
#
# ra_28 = gh_data_28['col5'][:]
# dec_28 = gh_data_28['col6'][:]
# f606_28 = gh_data_28['col3'][:]
# f814_28 = gh_data_28['col4'][:]

# %%
ra_select = np.hstack([ra_08, ra_14, ra_16, ra_17, ra_20, ra_22, ra_24, ra_26, ra_28])
dec_select = np.hstack([dec_08, dec_14, dec_16, dec_17, dec_20, dec_22, dec_24, dec_26, dec_28])
f606_select = np.hstack([f606_08, f606_14, f606_16, f606_17, f606_20, f606_22, f606_24, f606_26, f606_28])
f814_select = np.hstack([f814_08, f814_14, f814_16, f814_17, f814_20, f814_22, f814_24, f814_26, f814_28])

# %% [markdown]
# ###SAME AS PREVIOUS CELL BUT WITH ALL FIELDS###
#
# ra_all = np.hstack([ra_01, ra_02, ra_03, ra_04, ra_05, ra_06, ra_07, ra_08, ra_09, ra_10, ra_11, ra_12, ra_13, ra_14, ra_15, ra_16, ra_17, ra_18, ra_19, ra_20, ra_21, ra_22, ra_23, ra_24, ra_25, ra_26, ra_27, ra_28])
# dec_all = np.hstack([dec_01, dec_02, dec_03, dec_04, dec_05, dec_06, dec_07, dec_08, dec_09, dec_10, dec_11, dec_12, dec_13, dec_14, dec_15, dec_16, dec_17, dec_18, dec_19, dec_20, dec_21, dec_22, dec_23, dec_24, dec_25, dec_26, dec_27, dec_28])
# f606_all = np.hstack([f606_01, f606_02, f606_03, f606_04, f606_05, f606_06, f606_07, f606_08, f606_09, f606_10, f606_11, f606_12, f606_13, f606_14, f606_15, f606_16, f606_17, f606_18, f606_19, f606_20, f606_21, f606_22, f606_23, f606_24, f606_25, f606_26, f606_27, f606_28])
# f814_all = np.hstack([f814_01, f814_02, f814_03, f814_04, f814_05, f814_06, f814_07, f814_08, f814_09, f814_10, f814_11, f814_12, f814_13, f814_14, f814_15, f814_16, f814_17, f814_18, f814_19, f814_20, f814_21, f814_22, f814_23, f814_24, f814_25, f814_26, f814_27, f814_28])

# %% [markdown]
# [Now we make a color-magnitude diagram. One plots F606W-F814W magnitude along the x-axis (a color) as a proxy for temperature (using Wein's law). The y-axis is F814W magnitude, as a proxy for luminosity, but because they're magnitudes they're backwards :) ]

# %%
figure(figsize(18,18))

plt.subplot(4,3,11)
plot(f606_06-f814_06,f814_06, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 06')

plt.subplot(4,3,1)
plot(f606_08-f814_08,f814_08, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 08')

plt.subplot(4,3,2)
plot(f606_14-f814_14,f814_14, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 14')

plt.subplot(4,3,3)
plot(f606_16-f814_16,f814_16, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 16')

plt.subplot(4,3,4)
plot(f606_17-f814_17,f814_17, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 17')

plt.subplot(4,3,5)
plot(f606_20-f814_20,f814_20, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 20')

plt.subplot(4,3,6)
plot(f606_22-f814_22,f814_22, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 22')

plt.subplot(4,3,7)
plot(f606_24-f814_24,f814_24, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 24')

plt.subplot(4,3,8)
plot(f606_26-f814_26,f814_26, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 26')

plt.subplot(4,3,9)
plot(f606_28-f814_28,f814_28, 'ko', alpha=0.15)
axis([-1,2.5,27,23])
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 28')


plt.show()

# %% [markdown]
# ###SAME AS PREVIOUS CELL BUT WITH ALL FIELDS###
#
# figure(figsize(42,24))
#
# plt.subplot(4,7,1)
# plot(f606_01-f814_01,f814_01, 'bo', alpha=0.15)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
# axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 01')
#
# plt.subplot(4,7,2)
# plot(f606_02-f814_02,f814_02, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 02')
#
# plt.subplot(4,7,3)
# plot(f606_03-f814_03,f814_03, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 03')
#
# plt.subplot(4,7,4)
# plot(f606_04-f814_04,f814_04, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 04')
#
# plt.subplot(4,7,5)
# plot(f606_05-f814_05,f814_05, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 05')
#
# plt.subplot(4,7,6)
# plot(f606_06-f814_06,f814_06, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 06')
#
# plt.subplot(4,7,7)
# plot(f606_07-f814_07,f814_07, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 07')
#
# plt.subplot(4,7,8)
# plot(f606_08-f814_08,f814_08, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 08')
#
# plt.subplot(4,7,9)
# plot(f606_09-f814_09,f814_09, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 09')
#
# plt.subplot(4,7,10)
# plot(f606_10-f814_10,f814_10, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 10')
#
# plt.subplot(4,7,11)
# plot(f606_11-f814_11,f814_11, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 11')
#
# plt.subplot(4,7,12)
# plot(f606_12-f814_12,f814_12, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 12')
#
# plt.subplot(4,7,13)
# plot(f606_13-f814_13,f814_13, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 13')
#
# plt.subplot(4,7,14)
# plot(f606_14-f814_14,f814_14, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 14')
#
# plt.subplot(4,7,15)
# plot(f606_15-f814_15,f814_15, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 15')
#
# plt.subplot(4,7,16)
# plot(f606_16-f814_16,f814_16, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 16')
#
# plt.subplot(4,7,17)
# plot(f606_17-f814_17,f814_17, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 17')
#
# plt.subplot(4,7,18)
# plot(f606_18-f814_18,f814_18, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 18')
#
# plt.subplot(4,7,19)
# plot(f606_19-f814_19,f814_19, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 19')
#
# plt.subplot(4,7,20)
# plot(f606_20-f814_20,f814_20, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 20')
#
# plt.subplot(4,7,21)
# plot(f606_21-f814_21,f814_21, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 21')
#
# plt.subplot(4,7,22)
# plot(f606_22-f814_22,f814_22, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 22')
#
# plt.subplot(4,7,23)
# plot(f606_23-f814_23,f814_23, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 23')
#
# plt.subplot(4,7,24)
# plot(f606_24-f814_24,f814_24, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 24')
#
# plt.subplot(4,7,25)
# plot(f606_25-f814_25,f814_25, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 25')
#
# plt.subplot(4,7,26)
# plot(f606_26-f814_26,f814_26, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 26')
#
# plt.subplot(4,7,27)
# plot(f606_27-f814_27,f814_27, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 27')
#
# plt.subplot(4,7,28)
# plot(f606_28-f814_28,f814_28, 'bo', alpha=0.15)
# axis([-1,2.5,27,23])
# xlabel('F606W-F814W')
# ylabel('F814W')
# plt.title('Field 28')
#
#
# plt.show()

# %% [markdown]
# [Select bright stars (for the sake of argument), then plot all stars up, and overplot the bright ones up in ra/dec in blue (the equivalent of longitude and latitude on the sky) space. RA has the amusing convention of being plotted backwards (because you're on the inside of the celestial sphere looking out, sigh).]

# %% [markdown]
# EDIT: I have selected what stars I have deemed to be both "bright" and "blue" and plotted them as bright blue circles. Those stars which are "blue" but not "bright" are dimmer blue circles, and the stars that are not blue at all are plotted faintly in red.

# %%
figure(figsize(12,12))
blue_06, = where (((-0.4) < (f606_06-f814_06)) & ((f606_06-f814_06) < (0.2)))
briblu_06, = where (((-0.4) < (f606_06-f814_06)) & ((f606_06-f814_06) < (0.2)) & ((23) < (f814_06)) & ((f814_06) < (27)))
plot(ra_06,dec_06,'ro',alpha=0.15)
plot(ra_06[blue_06],dec_06[blue_06],'bo',alpha=0.35)
plot(ra_06[briblu_06],dec_06[briblu_06],'bo',alpha=0.55)
axis([max(ra_06),min(ra_06),min(dec_06),max(dec_06)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 06')

# %%
figure(figsize(12,12))
blue_20, = where (((-0.4) < (f606_20-f814_20)) & ((f606_20-f814_20) < (0.2)))
briblu_20, = where (((-0.4) < (f606_20-f814_20)) & ((f606_20-f814_20) < (0.2)) & ((23) < (f814_20)) & ((f814_20) < (27)))
plot(ra_20,dec_20,'ro',alpha=0.15)
plot(ra_20[blue_20],dec_20[blue_20],'bo',alpha=0.35)
plot(ra_20[briblu_20],dec_20[briblu_20],'bo',alpha=0.55)
axis([max(ra_20),min(ra_20),min(dec_20),max(dec_20)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 20')

# %% [markdown]
# Now I have plotted all of the "bright blue" stars found in all 28 fields of the M81 GHOSTS data.

# %%
figure(figsize(12,12))
blue, = where (((-0.4) < (f606_select-f814_select)) & ((f606_select-f814_select) < (0.2)))
briblu, = where (((-0.4) < (f606_select-f814_select)) & ((f606_select-f814_select) < (0.2)) & ((23) < (f814_select)) & ((f814_select) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))

plot(ra_select,dec_select, 'ro', alpha=.05)
plot(ra_select[blue],dec_select[blue],'bo',alpha=0.35)
plot(ra_select[briblu],dec_select[briblu],'bo',alpha=0.55)
axis([max(ra_select),min(ra_select),min(dec_select),max(dec_select)])
xlabel('RA')
ylabel('Dec')
plt.title('Select Fields')

# %%
bluecon, = where (((-0.4) < (f606_06-f814_06)) & ((f606_06-f814_06) < (0.2)))
briblucon, = where (((-0.4) < (f606_06-f814_06)) & ((f606_06-f814_06) < (0.2)) & ((23) < (f814_06)) & ((f814_06) < (27))) #where(((23) < (f814_06[bluecon])) & ((f814_06[bluecon) < (27)))

print np.size(bluecon)
print np.size(briblucon)
# Out:
# 25
# 25

# %%
#blue2, = where (((-0.4) < (f606_select-f814_select)) & ((f606_select-f814_select) < (0.2)))
#briblu2, = where (((-0.4) < (f606_select-f814_select)) & ((f606_select-f814_select) < (0.2)) & ((23) < (f814_select)) & ((f814_select) < (27))) #where(((23) < (f814_miass[blue2])) & ((f814_miass[blue2]) < (27)))

#print blue2
#print briblu2

ra_selectbb = ra_select[briblu]
dec_selectbb = dec_select[briblu]

ra_controlbb = ra_06[briblucon]
dec_controlbb = dec_06[briblucon]


print np.size(f606_06-f814_06)
print np.size(f814_06)

print np.size(f606_select-f814_select)
print np.size(f814_select)

print np.size((f606_06-f814_06)[briblucon])
print np.size((f814_06)[briblucon])

print np.size((f606_select-f814_select)[briblu])
print np.size((f814_select)[briblu])


print np.size(ra_selectbb)
print np.size(dec_selectbb)

print np.size(ra_controlbb)
print np.size(dec_controlbb)
# Out:
# 868
# 868
# 2176
# 2176
# 25
# 25
# 144
# 144
# 144
# 144
# 25
# 25

# %%
bb_x, bb_y = w.all_world2pix(ra_selectbb, dec_selectbb, 0)

# Find the nearest integer pixel
bb_x = np.round(bb_x).astype(int)
bb_y = np.round(bb_y).astype(int)

# %%
print np.size(bb_x)
print np.size(bb_y)

#print bb_x
#print bb_y
# Out:
# 144
# 144

# %%
figure(figsize(579/74, 687/74))
plt.scatter(x=bb_x, y=bb_y, c='b', marker='^', edgecolors='none')
axis([min(bb_x),max(bb_x),min(bb_y),max(bb_y)])
xlabel('pix_x')
ylabel('pix_y')
plt.title('test 2: the quest for test')

# %%
scoords = SkyCoord(ra=pixra, dec=pixdec, unit=(u.deg, u.deg), frame='fk4')

# %%
sc_icrs = scoords.transform_to('icrs')

# %%
figure(figsize(579/74, 687/74))
plt.scatter(x=sc_icrs.ra.deg, y=sc_icrs.dec.deg, c=pixdata, marker=',', edgecolors='none', cmap=matplotlib.cm.gray_r)
axis([max(sc_icrs.ra.deg),min(sc_icrs.ra.deg),min(sc_icrs.dec.deg),max(sc_icrs.dec.deg)])
xlabel('ra')
ylabel('dec')
plt.title('test 3: the final exam')

# %%
figure(figsize(579/74, 687/74))
plt.scatter(x=sc_icrs.ra.deg, y=sc_icrs.dec.deg, c=pixdata, marker=',', edgecolors='none', cmap=matplotlib.cm.gray_r)
plt.scatter(x=ra_selectbb, y=dec_selectbb, c='b', marker='^', edgecolors='none')
axis([max(max(ra_selectbb),max(sc_icrs.ra.deg)),min(min(ra_selectbb),min(sc_icrs.ra.deg)),min(min(dec_selectbb),min(sc_icrs.dec.deg)),max(max(dec_selectbb),max(sc_icrs.dec.deg))])
xlabel('ra')
ylabel('dec')
plt.title('this is not a test')

# %% [markdown]
# ###OLDER WORK BELOW###

# %% [markdown]
# Here I am comparing the CMDs of the bright blue stars in MiASs and the blue stars in a control field--I chose Field 6.

# %%
figure(figsize(12,6))

plt.subplot(1,2,1)
plot((f606_select-f814_select)[briblu2],f814_select[briblu2], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Select CMD (blue)')

plt.subplot(1,2,2)
plot((f606_06-f814_06)[briblucon],f814_06[briblucon], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Control: Field 6 CMD (blue)')

plt.show()

# %% [markdown]
# And here I am comparing the CMDs (for all stars--not just the bright blue ones) of each of the MiASs fields against that of Field 6.

# %%
figure(figsize(12,6))

plt.subplot(1,2,1)
plot(f606_select-f814_select,f814_select, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Select CMD (all)')

plt.subplot(1,2,2)
plot(f606_06-f814_06,f814_06, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Control: Field 06 CMD (all)')

# %% [markdown]
# At this point, I began exploring some of the outer major axis fields, as they were returning "blue" stars that seemed a little out of line.

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_06-f814_06)) & ((f606_06-f814_06) < (0.2)))
briblu, = where (((-0.4) < (f606_06-f814_06)) & ((f606_06-f814_06) < (0.2)) & ((23) < (f814_06)) & ((f814_06) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_06,dec_06, 'ro', alpha=.15)
plot(ra_06[blue],dec_06[blue],'go',alpha=0.35)
plot(ra_06[briblu],dec_06[briblu],'bo',alpha=0.55)
axis([max(ra_06),min(ra_06),min(dec_06),max(dec_06)])
xlabel('RA')
ylabel('Dec')
plt.title('Control: Field 06')


plt.subplot(1,3,2)
plot((f606_06-f814_06)[briblu],f814_06[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Control: Field 06 Blue CMD')


plt.subplot(1,3,3)
plot(f606_06-f814_06,f814_06, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Control: Field 06 CMD')



num_babies_06 = size( ra_06[briblu] )

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_08-f814_08)) & ((f606_08-f814_08) < (0.2)))
briblu, = where (((-0.4) < (f606_08-f814_08)) & ((f606_08-f814_08) < (0.2)) & ((23) < (f814_08)) & ((f814_08) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_08,dec_08, 'ro', alpha=.15)
plot(ra_08[blue],dec_08[blue],'go',alpha=0.35)
plot(ra_08[briblu],dec_08[briblu],'bo',alpha=0.55)
axis([max(ra_08),min(ra_08),min(dec_08),max(dec_08)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 08')


plt.subplot(1,3,2)
plot((f606_08-f814_08)[briblu],f814_08[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 08 Blue CMD')


plt.subplot(1,3,3)
plot(f606_08-f814_08,f814_08, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 08 CMD')



num_babies_08 = size( ra_08[briblu] )

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_14-f814_14)) & ((f606_14-f814_14) < (0.2)))
briblu, = where (((-0.4) < (f606_14-f814_14)) & ((f606_14-f814_14) < (0.2)) & ((23) < (f814_14)) & ((f814_14) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_14,dec_14, 'ro', alpha=.15)
plot(ra_14[blue],dec_14[blue],'go',alpha=0.35)
plot(ra_14[briblu],dec_14[briblu],'bo',alpha=0.55)
axis([max(ra_14),min(ra_14),min(dec_14),max(dec_14)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 14')


plt.subplot(1,3,2)
plot((f606_14-f814_14)[briblu],f814_14[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 14 Blue CMD')


plt.subplot(1,3,3)
plot(f606_14-f814_14,f814_14, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 14 CMD')



num_babies_14 = size( ra_14[briblu] )

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_16-f814_16)) & ((f606_16-f814_16) < (0.2)))
briblu, = where (((-0.4) < (f606_16-f814_16)) & ((f606_16-f814_16) < (0.2)) & ((23) < (f814_16)) & ((f814_16) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_16,dec_16, 'ro', alpha=.15)
plot(ra_16[blue],dec_16[blue],'go',alpha=0.35)
plot(ra_16[briblu],dec_16[briblu],'bo',alpha=0.55)
axis([max(ra_16),min(ra_16),min(dec_16),max(dec_16)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 16')


plt.subplot(1,3,2)
plot((f606_16-f814_16)[briblu],f814_16[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 16 Blue CMD')


plt.subplot(1,3,3)
plot(f606_16-f814_16,f814_16, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 16 CMD')



num_babies_16 = size( ra_16[briblu] )

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_17-f814_17)) & ((f606_17-f814_17) < (0.2)))
briblu, = where (((-0.4) < (f606_17-f814_17)) & ((f606_17-f814_17) < (0.2)) & ((23) < (f814_17)) & ((f814_17) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_17,dec_17, 'ro', alpha=.15)
plot(ra_17[blue],dec_17[blue],'go',alpha=0.35)
plot(ra_17[briblu],dec_17[briblu],'bo',alpha=0.55)
axis([max(ra_17),min(ra_17),min(dec_17),max(dec_17)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 17')


plt.subplot(1,3,2)
plot((f606_17-f814_17)[briblu],f814_17[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 17 Blue CMD')


plt.subplot(1,3,3)
plot(f606_17-f814_17,f814_17, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 17 CMD')



num_babies_17 = size( ra_17[briblu] )

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_20-f814_20)) & ((f606_20-f814_20) < (0.2)))
briblu, = where (((-0.4) < (f606_20-f814_20)) & ((f606_20-f814_20) < (0.2)) & ((23) < (f814_20)) & ((f814_20) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_20,dec_20, 'ro', alpha=.15)
plot(ra_20[blue],dec_20[blue],'go',alpha=0.35)
plot(ra_20[briblu],dec_20[briblu],'bo',alpha=0.55)
axis([max(ra_20),min(ra_20),min(dec_20),max(dec_20)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 20')


plt.subplot(1,3,2)
plot((f606_20-f814_20)[briblu],f814_20[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 20 Blue CMD')


plt.subplot(1,3,3)
plot(f606_20-f814_20,f814_20, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 20 CMD')



num_babies_20 = size( ra_20[briblu] )

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_22-f814_22)) & ((f606_22-f814_22) < (0.2)))
briblu, = where (((-0.4) < (f606_22-f814_22)) & ((f606_22-f814_22) < (0.2)) & ((23) < (f814_22)) & ((f814_22) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_22,dec_22, 'ro', alpha=.15)
plot(ra_22[blue],dec_22[blue],'go',alpha=0.35)
plot(ra_22[briblu],dec_22[briblu],'bo',alpha=0.55)
axis([max(ra_22),min(ra_22),min(dec_22),max(dec_22)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 22')


plt.subplot(1,3,2)
plot((f606_22-f814_22)[briblu],f814_22[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 22 Blue CMD')


plt.subplot(1,3,3)
plot(f606_22-f814_22,f814_22, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 22 CMD')



num_babies_22 = size( ra_22[briblu] )

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_24-f814_24)) & ((f606_24-f814_24) < (0.2)))
briblu, = where (((-0.4) < (f606_24-f814_24)) & ((f606_24-f814_24) < (0.2)) & ((23) < (f814_24)) & ((f814_24) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_24,dec_24, 'ro', alpha=.15)
plot(ra_24[blue],dec_24[blue],'go',alpha=0.35)
plot(ra_24[briblu],dec_24[briblu],'bo',alpha=0.55)
axis([max(ra_24),min(ra_24),min(dec_24),max(dec_24)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 24')


plt.subplot(1,3,2)
plot((f606_24-f814_24)[briblu],f814_24[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 24 Blue CMD')


plt.subplot(1,3,3)
plot(f606_24-f814_24,f814_24, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 24 CMD')



num_babies_24 = size( ra_24[briblu] )

# %%
figure(figsize(18,6))

plt.subplot(1,3,1)
blue, = where (((-0.4) < (f606_26-f814_26)) & ((f606_26-f814_26) < (0.2)))
briblu, = where (((-0.4) < (f606_26-f814_26)) & ((f606_26-f814_26) < (0.2)) & ((23) < (f814_26)) & ((f814_26) < (27))) #where(((23) < (f814_all[blue])) & ((f814_all[blue]) < (27)))
plot(ra_26,dec_26, 'ro', alpha=.15)
plot(ra_26[blue],dec_26[blue],'go',alpha=0.35)
plot(ra_26[briblu],dec_26[briblu],'bo',alpha=0.55)
axis([max(ra_26),min(ra_26),min(dec_26),max(dec_26)])
xlabel('RA')
ylabel('Dec')
plt.title('Field 26')


plt.subplot(1,3,2)
plot((f606_26-f814_26)[briblu],f814_26[briblu], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 26 Blue CMD')


plt.subplot(1,3,3)
plot(f606_26-f814_26,f814_26, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Field 26 CMD')



num_babies_26 = size( ra_26[briblu] )

# %%
#num_babies_list = np.hstack([num_babies_08, num_babies_14, num_babies_16, num_babies_17, num_babies_20, num_babies_22, num_babies_24, num_babies_26])
num_babies_plus_06 = np.hstack([num_babies_06, num_babies_08, num_babies_14, num_babies_16, num_babies_17, num_babies_20, num_babies_22, num_babies_24, num_babies_26])

num_babies_tuple = tuple(num_babies_plus_06)

N = 9
ind = np.arange(N)    # the x locations for the groups

p1 = plt.bar(ind, num_babies_tuple, align = 'center')

plt.ylabel('Number of Bright Blue Stars')
plt.title('Babies per Field')
plt.xticks(ind, ('Field 06','Field 08','Field 14','Field 16','Field 17','Field 20','Field 22','Field 24','Field 26'))

plt.show()

# %%
#num_babies_list = np.hstack([num_babies_08, num_babies_14, num_babies_16, num_babies_17, num_babies_20, num_babies_22, num_babies_24, num_babies_26])
num_babies_plus_06 = np.hstack([num_babies_06, num_babies_08, num_babies_14, num_babies_16, num_babies_17, num_babies_20, num_babies_22, num_babies_24, num_babies_26])

num_babies_tuple = tuple(num_babies_plus_06)
#print num_babies_tuple

babies_per_square_kpc = num_babies_plus_06 / (11.72)
babies_p_s_kpc_tuple = tuple(babies_per_square_kpc)

N = 9
ind = np.arange(N)    # the x locations for the groups

p1 = plt.bar(ind, babies_p_s_kpc_tuple, align = 'center')

plt.ylabel('BB Star Density')
plt.title('BB Stars per square kpc, by Field')
plt.xticks(ind, ('Field 06','Field 08','Field 14','Field 16','Field 17','Field 20','Field 22','Field 24','Field 26'))


def autolabel(allplots):
    """
    Attach a text label above each bar displaying its height
    """
    for eachplot in allplots:
        height = eachplot.get_height()
        text(eachplot.get_x() + eachplot.get_width()/2., 1.05*height,
                '%f' % height,
                ha='center', va='bottom')

autolabel(p1)


plt.show()

# %%
blue_x = list()
blue_y = list()
blue_xyindex = 0
imax = len(ra_selectbb)/1
jmax = len(dec_selectbb)/1
for i in range(imax):
    for j in range(jmax):
        WCS_HI = WCS('M81HIM0.fits')
        pic_x, pic_y = WCS_HI.all_world2pix(i*1,j*1,0)
        pixra.append(lon)
        pixdec.append(lat)
        radecindex = radecindex+1
plot(pixra,pixdec,'k.')

# %% [markdown]
# After looking closed at the data, Eric and I determined that the data from the WFC3 fields simply was not up to the caliber that we needed and that we should no longer consider it during this endeavor. Instead, we will only look at the ACS fields. In particular, the data I am about to group together comes from all of the outer fields taken from the ACS, which include 20, 22, 24, and 26 from the minor axis, and 14, 16, and 17 from the major axis. I will also include field 28 from the opposite side of the minor axis.

# %%
ra_out = np.hstack([ra_08, ra_14, ra_16, ra_17, ra_20, ra_22, ra_24, ra_26, ra_28])
dec_out = np.hstack([dec_08, dec_14, dec_16, dec_17, dec_20, dec_22, dec_24, dec_26, dec_28])
f606_out = np.hstack([f606_08, f606_14, f606_16, f606_17, f606_20, f606_22, f606_24, f606_26, f606_28])
f814_out = np.hstack([f814_08, f814_14, f814_16, f814_17, f814_20, f814_22, f814_24, f814_26, f814_28])

#ra_in = np.hstack([ra_01, ra_02, ra_03, ra_04, ra_05, ra_06, ra_07, ra_09, ra_10, ra_11, ra_12])
#dec_in = np.hstack([dec_01, dec_02, dec_03, dec_04, dec_05, dec_06, dec_07, dec_09, dec_10, dec_11, dec_12])
#f606_in = np.hstack([f606_01, f606_02, f606_03, f606_04, f606_05, f606_06, f606_07, f606_09, f606_10, f606_11, f606_12])
#f814_in = np.hstack([f814_01, f814_02, f814_03, f814_04, f814_05, f814_06, f814_07, f814_09, f814_10, f814_11, f814_12])

#ra_wfc3 = np.hstack([ra_13, ra_15, ra_18, ra_19, ra_21, ra_23, ra_25, ra_27])
#dec_wfc3 = np.hstack([dec_13, dec_15, dec_18, dec_19, dec_21, dec_23, dec_25, dec_27])
#f606_wfc3 = np.hstack([f606_13, f606_15, f606_18, f606_19, f606_21, f606_23, f606_25, f606_27])
#f814_wfc3 = np.hstack([f814_13, f814_15, f814_18, f814_19, f814_21, f814_23, f814_25, f814_27])


blueout, = where (((-0.4) < (f606_out-f814_out)) & ((f606_out-f814_out) < (0.2)))
bribluout, = where (((-0.4) < (f606_out-f814_out)) & ((f606_out-f814_out) < (0.2)) & ((23) < (f814_out)) & ((f814_out) < (27)))

#bluein, = where (((-0.4) < (f606_in-f814_in)) & ((f606_in-f814_in) < (0.2)))
#bribluin, = where (((-0.4) < (f606_in-f814_in)) & ((f606_in-f814_in) < (0.2)) & ((23) < (f814_in)) & ((f814_in) < (27)))

#bluewfc3, = where (((-0.4) < (f606_wfc3-f814_wfc3)) & ((f606_wfc3-f814_wfc3) < (0.2)))
#bribluwfc3, = where (((-0.4) < (f606_wfc3-f814_wfc3)) & ((f606_wfc3-f814_wfc3) < (0.2)) & ((23) < (f814_wfc3)) & ((f814_wfc3) < (27)))

# %%
figure(figsize(12,12))

plot(ra_out,dec_out, 'ro', alpha=.05)
plot(ra_out[blueout],dec_out[blueout],'yo',alpha=0.35)
plot(ra_out[bribluout],dec_out[bribluout],'bo',alpha=0.55)
axis([max(ra_out),min(ra_out),min(dec_out),max(dec_out)])
xlabel('RA')
ylabel('Dec')
plt.title('New Fields')

# %% [markdown]
# ###Not usable without al fields###
#
# figure(figsize(12,12))
#
# plot(ra_out,dec_out, 'ro', alpha=.05)
# plot(ra_out[blueout],dec_out[blueout],'yo',alpha=0.15)
# plot(ra_out[bribluout],dec_out[bribluout],'bo',alpha=0.75)
#
# plot(ra_in,dec_in, 'ro', alpha=.01)
# plot(ra_in[bluein],dec_in[bluein],'yo',alpha=0.05)
# plot(ra_in[bribluin],dec_in[bribluin],'co',alpha=0.15)
#
# plot(ra_wfc3,dec_wfc3, 'ro', alpha=.01)
# plot(ra_wfc3[bluewfc3],dec_wfc3[bluewfc3],'yo',alpha=0.05)
# plot(ra_wfc3[bribluwfc3],dec_wfc3[bribluwfc3],'go',alpha=0.15)
#
# axis([max(ra_out),min(ra_out),min(dec_out),max(dec_out)])
# xlabel('RA')
# ylabel('Dec')
# plt.title('Outer Fields with Context')

# %%
#figure(figsize(12,6))

#plt.subplot(1,2,1)
#plot(f606_out-f814_out,f814_out, 'ko', alpha=0.25)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
#axis([-1,2.5,27,23])  # this sets up the axes, and the next one the labels
#xlabel('F606W-F814W')
#ylabel('F814W')
#plt.title('Outer CMD (all)')

#plt.subplot(1,2,2)

figure(figsize(6,6))

plot((f606_out-f814_out)[bribluout],f814_out[bribluout], 'bo', alpha=0.55)   # alpha=0.05 is to make it partly transparent; 'ko' is a black circle
plot((f606_out-f814_out),f814_out, 'ro', alpha=0.15)
x1 = -0.4
x2 = 0.2
y1 = 27
y2 = 23
plot((x1,x2),(y1,y1),'b-')
plot((x1,x2),(y2,y2),'b-')
plot((x1,x1),(y1,y2),'b-')
plot((x2,x2),(y1,y2),'b-')
axis([-1,2.5,27.25,22.75])  # this sets up the axes, and the next one the labels
xlabel('F606W-F814W')
ylabel('F814W')
plt.title('Outer CMD ("Blue" Parameters Shown)')

plt.savefig('Outer_CMD_blue_parameters_shown.png', dpi= 500, facecolor='w', bbox_inches= "tight", format='png', transparent=True)

# %%
print size( f814_out[bribluout] )
print size( (f606_out-f814_out)[bribluout] )

print f814_out[bribluout]
# Out:
# 144
# 144
# [ 23.395  23.603  23.544  23.886  23.746  24.077  23.901  23.873  24.151
#   24.094  24.136  24.64   24.647  24.443  24.613  25.487  24.871  24.907
#   24.893  25.027  24.808  24.967  25.041  24.856  25.067  25.183  25.106
#   25.062  25.211  25.235  25.104  25.223  25.421  25.215  25.347  25.25
#   25.301  25.133  25.291  25.423  25.52   25.497  25.654  25.575  25.503
#   25.657  25.432  25.494  25.809  25.552  25.764  25.623  25.818  25.854
#   25.634  25.809  25.955  25.548  26.073  26.073  25.731  25.948  25.817
#   26.019  25.818  25.968  26.017  26.079  26.05   26.249  26.195  26.202
#   26.423  26.283  26.202  26.054  26.012  26.149  26.436  26.105  26.38
#   26.354  26.438  26.35   26.304  23.594  25.181  25.875  25.881  25.966
#   26.116  26.299  23.496  23.967  24.159  24.332  24.283  24.535  24.696
#   25.009  25.062  25.094  25.364  25.164  25.549  25.455  25.512  25.824
#   26.29   25.888  25.882  26.067  26.384  26.102  26.425  26.326  26.147
#   26.176  26.245  26.508  26.445  23.25   26.016  26.442  24.763  25.656
#   25.635  26.583  26.597  26.309  26.643  26.594  25.173  23.735  25.369
#   26.488  26.469  26.587  24.676  26.034  26.602  25.919  26.18   26.551]

# %%
ra_outblue = hstack([ra_out[bribluout]])
dec_outblue = hstack([dec_out[bribluout]])

scoords_outblue = SkyCoord(ra_outblue,
                   dec_outblue,
                   unit=(u.deg, u.deg), frame='icrs')

ra_inblue = hstack([ra_in[bribluin]])
dec_inblue = hstack([dec_in[bribluin]])

scoords_inblue = SkyCoord(ra_inblue,
                   dec_inblue,
                   unit=(u.deg, u.deg), frame='icrs')

# %%
sc1950_out = scoords_outblue.transform_to(FK4)
fig_out = aplpy.FITSFigure('M81HIM0.FITS')
fig_out.show_grayscale()
#fig_out.set_theme('pretty')
fig_out.show_circles(sc1950_out.ra.deg,sc1950_out.dec.deg,1./150.,facecolor='cyan',edgecolor='blue')
fig_out.add_grid()
filename = "HI_FITS_Map_and_Stars.png"
fig_out.save(filename, dpi=500, transparent=True, adjust_bbox=True, format='png')

#sc1950_in = scoords_inblue.transform_to(FK4)
#fig_in = aplpy.FITSFigure('M81HIM0.FITS')
#fig_in.show_grayscale()
#fig_in.show_circles(sc1950_in.ra.deg,sc1950_in.dec.deg,10./3600.,facecolor='cyan',edgecolor='cyan')
#fig_in.add_grid()
# Out:
# INFO:astropy:Setting slices=[0]
# INFO: Setting slices=[0] [aplpy.core]
# INFO
# INFO:astropy:Auto-setting vmin to -3.178e+02
# INFO:astropy:Auto-setting vmax to  3.494e+03
# : Auto-setting vmin to -3.178e+02 [aplpy.core]
# INFO: Auto-setting vmax to  3.494e+03 [aplpy.core]

# %% [markdown]
# Plot colour-mag of outer fields. Some, less dense, etc. $\checkmark$
#
# $\space \space \space \space \space$ Look at those fields' images
#
# $\space \space \space \space \space$ Compare cmag to field 8, something like it [choose 6] $\checkmark$
#
# Do same plots for M83
#
# (clean up the colours in the above plot) $\checkmark$

# %% [markdown]
# CMD for MiASs and control $\checkmark$
#
# Field 16 $\checkmark$
#
# Field 12 $\checkmark$
